# %%
import pandas as pd
import seaborn as sns

insurance = pd.read_csv('../data/insurance.csv')

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.histplot(insurance['charges']);

# %%
sns.boxplot(x=insurance['charges'])
# Out:
# <Axes: xlabel='charges'>

# %%
sns.boxenplot(x=insurance['charges']);

# %%
sns.histplot(x=insurance['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(x=insurance['bmi']);

# %%
insurance['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
insurance['smoker'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %%
insurance['region'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='region'>

# %%
insurance['sex'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %%
#
# ! video 33. Linear Relationships in Python
insurance[['charges', 'age']].corr()
# Out:
#           charges       age
# charges  1.000000  0.299008
# age      0.299008  1.000000

# %%
insurance.corr(numeric_only=True)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(insurance.corr(numeric_only=True), vmin=-1, vmax=1, annot=True, cmap='coolwarm');

# %%
#
# ! video 34. Feature-Target Relationships
sns.scatterplot(data=insurance, x='age', y='charges', hue='smoker', alpha=0.5);

# %%
insurance.groupby('smoker')['charges'].mean().plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %%
#
# ! video 35. Feature-Feature Relationships
sns.scatterplot(data=insurance, x='age', y='bmi');

# %%
insurance.groupby('smoker')['age'].mean().plot.bar();

# %%
insurance.groupby('smoker')['bmi'].mean().plot.bar();

# %%
#
# ! video 36. PROTIP: Pairplots & Lmplots
sns.pairplot(insurance, corner=True);

# %%
sns.lmplot(data=insurance, x='bmi', y='charges', hue='smoker', height=5, aspect=2);
